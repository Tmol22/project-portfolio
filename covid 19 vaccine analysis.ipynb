# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
data = pd.read_csv(r"C:\Users\HP\Desktop\project portfolio\project\country_vaccinations.csv")
data.head()
# Out:
#      country iso_code        date  total_vaccinations  people_vaccinated  \
# 0  Argentina      ARG  2020-12-29               700.0                NaN
# 1  Argentina      ARG  2020-12-30                 NaN                NaN
# 2  Argentina      ARG  2020-12-31             32013.0                NaN
# 3  Argentina      ARG  2021-01-01                 NaN                NaN
# 4  Argentina      ARG  2021-01-02                 NaN                NaN
#
#    people_fully_vaccinated  daily_vaccinations_raw  daily_vaccinations  \
# 0                      NaN                     NaN                 NaN
# 1                      NaN                     NaN             15656.0
# 2                      NaN                     NaN             15656.0
# 3                      NaN                     NaN             11070.0
# 4                      NaN                     NaN              8776.0
#
#    total_vaccinations_per_hundred  people_vaccinated_per_hundred  \
# ...

# %%
data.describe()
# Out:
#        total_vaccinations  people_vaccinated  people_fully_vaccinated  \
# count        8.730000e+02       8.420000e+02             1.980000e+02
# mean         5.636304e+05       5.276886e+05             1.601797e+05
# std          1.755851e+06       1.590297e+06             3.869539e+05
# min          0.000000e+00       0.000000e+00             2.000000e+00
# 25%          1.498000e+04       1.458950e+04             1.952750e+03
# 50%          6.075300e+04       5.859850e+04             8.362000e+03
# 75%          2.688810e+05       2.697472e+05             2.268938e+05
# max          1.910796e+07       1.624309e+07             2.756953e+06
#
#        daily_vaccinations_raw  daily_vaccinations  \
# count            7.000000e+02         1266.000000
# mean             4.517910e+04        42295.565561
# std              1.224248e+05       110200.570930
# min              0.000000e+00            1.000000
# 25%              1.694750e+03         1645.250000
# ...

# %%
pd.to_datetime(data.date)
data.country.value_counts()
# Out:
# Wales                   40
# Canada                  40
# Northern Ireland        40
# Scotland                40
# China                   37
# Israel                  35
# United States           34
# United Kingdom          33
# England                 33
# Switzerland             30
# Russia                  30
# Chile                   30
# Mexico                  30
# Lithuania               29
# Bahrain                 29
# Czechia                 27
# Italy                   27
# Greece                  26
# Latvia                  26
# Portugal                26
# Norway                  26
# Germany                 26
# Estonia                 26
# Romania                 26
# Denmark                 26
# Poland                  25
# Malta                   25
# Argentina               25
# Bulgaria                25
# Belgium                 25
# Hungary                 25
# Iceland                 24
# Oman                    23
# Luxembourg              23
# ...

# %%
data = data[data.country.apply(lambda x: x not in ["England", "Scotland", "Wales", "Northern Ireland"])]
data.country.value_counts()
# Out:
# Canada                  40
# China                   37
# Israel                  35
# United States           34
# United Kingdom          33
# Switzerland             30
# Russia                  30
# Chile                   30
# Mexico                  30
# Bahrain                 29
# Lithuania               29
# Czechia                 27
# Italy                   27
# Denmark                 26
# Latvia                  26
# Germany                 26
# Romania                 26
# Greece                  26
# Portugal                26
# Norway                  26
# Estonia                 26
# Belgium                 25
# Bulgaria                25
# Poland                  25
# Malta                   25
# Argentina               25
# Hungary                 25
# Iceland                 24
# Finland                 23
# Luxembourg              23
# Costa Rica              23
# Oman                    23
# Sweden                  22
# Croatia                 21
# ...

# %%
data.vaccines.value_counts()
# Out:
# Pfizer/BioNTech                        667
# Moderna, Pfizer/BioNTech               267
# Sputnik V                               55
# Pfizer/BioNTech, Sinopharm              47
# CNBG, Sinovac                           37
# Oxford/AstraZeneca, Pfizer/BioNTech     33
# Pfizer/BioNTech, Pifzer/BioNTech        25
# Sinovac                                 19
# Sinopharm                               12
# Covaxin, Covishield                      8
# Name: vaccines, dtype: int64

# %%
df = data[["vaccines", "country"]]
df.head()
# Out:
#     vaccines    country
# 0  Sputnik V  Argentina
# 1  Sputnik V  Argentina
# 2  Sputnik V  Argentina
# 3  Sputnik V  Argentina
# 4  Sputnik V  Argentina

# %%
dict_ = {}
for i in df.vaccines.unique():
  dict_[i] = [df["country"][j] for j in df[df["vaccines"]==i].index]

vaccines = {}
for key, value in dict_.items():
  vaccines[key] = set(value)
for i, j in vaccines.items():
  print(f"{i}:>>{j}")JKiop
# Out:
# Sputnik V:>>{'Argentina', 'Russia'}
# Pfizer/BioNTech:>>{'Estonia', 'Oman', 'Slovakia', 'France', 'Belgium', 'Malta', 'Chile', 'Israel', 'Portugal', 'Saudi Arabia', 'Slovenia', 'Latvia', 'Romania', 'Sweden', 'Greece', 'Serbia', 'Finland', 'Cyprus', 'Croatia', 'Norway', 'Kuwait', 'Gibraltar', 'Poland', 'Switzerland', 'Ireland', 'Costa Rica', 'Austria', 'Singapore', 'Isle of Man', 'Mexico', 'Italy', 'Luxembourg'}
# Pfizer/BioNTech, Sinopharm:>>{'United Arab Emirates', 'Bahrain'}
# Sinovac:>>{'Turkey', 'Brazil'}
# Moderna, Pfizer/BioNTech:>>{'Netherlands', 'Czechia', 'Germany', 'United States', 'Bulgaria', 'Lithuania', 'Iceland', 'Canada', 'Denmark', 'Spain'}
# CNBG, Sinovac:>>{'China'}
# Pfizer/BioNTech, Pifzer/BioNTech:>>{'Hungary'}
# Covaxin, Covishield:>>{'India'}
# Sinopharm:>>{'Seychelles'}
# Oxford/AstraZeneca, Pfizer/BioNTech:>>{'United Kingdom'}

# %%
import plotly.express as px
import plotly.offline as py

vaccine_map = px.choropleth(data, locations = 'iso_code', color = 'vaccines')
vaccine_map.update_layout(height=300, margin={"r":0,"t":0,"l":0,"b":0})
vaccine_map.show()
# Out:
# <div>                            <div id="36ccfcf0-41ef-4eef-93d7-c3496bbb6a2f" class="plotly-graph-div" style="height:300px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("36ccfcf0-41ef-4eef-93d7-c3496bbb6a2f")) {                    Plotly.newPlot(                        "36ccfcf0-41ef-4eef-93d7-c3496bbb6a2f",                        [{"colorscale":[[0.0,"#636efa"],[1.0,"#636efa"]],"geo":"geo","hovertemplate":"vaccines=Sputnik V<br>iso_code=%{location}<extra></extra>","locations":["ARG","ARG","ARG","ARG","ARG","ARG","ARG","ARG","ARG","ARG","ARG","ARG","ARG","ARG","ARG","ARG","ARG","ARG","ARG","ARG","ARG","ARG","ARG","ARG","ARG","RUS","RUS","RUS","RUS","RUS","RUS","RUS","RUS","RUS","RUS","RUS","RUS","RUS","RUS","RUS","RUS","RUS","RUS","RUS","RUS","RUS","RUS","RUS","RUS","RUS","RUS","RUS","RUS",
# ...
